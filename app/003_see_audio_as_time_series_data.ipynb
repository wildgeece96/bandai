# %% [markdown]
# # スペクトログラムをある種の時系列データとみなして眺めてみる

# %%
import librosa
import librosa.display
import numpy as np 
import glob
import os
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import wavio
import IPython.display

import utils
import plot

# %%
raw_specs, noised_specs = utils.load_spectrograms("../data")

# %%
raw_specs[1].shape
# Out:
# (128, 228)

# %%
raw_specs[2].shape
# Out:
# (128, 95)

# %%
idx = 10
raw_spec = raw_specs[idx]

fig = plt.figure(figsize=(8,8))
ax = Axes3D(fig)
freqs = librosa.mel_frequencies()
steps = raw_spec.shape[1]
for i in range(0, 128):
    ax.plot(np.arange(steps), [freqs[i]]*steps, raw_spec[i])
ax.set_zlim([0, 50])
ax.set_ylabel("Frequency(Hz)")
ax.set_xlabel("Time step")
ax.set_zlabel("Amplitude")
ax.grid()
