# %% [markdown]
# # スペクトログラムをある種の時系列データとみなして眺めてみる

# %%
import librosa
import librosa.display
import numpy as np 
import glob
import os
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import wavio
import IPython.display

import utils
import plot

# %%
raw_specs, noised_specs = utils.load_spectrograms("../data")

# %%
raw_specs[1].shape
# Out:
# (128, 228)

# %%
raw_specs[2].shape
# Out:
# (128, 95)

# %%
idx = 2
raw_spec = raw_specs[idx]

fig = plt.figure(figsize=(8,8))
ax = Axes3D(fig)
freqs = librosa.mel_frequencies()
steps = raw_spec.shape[1]
for i in range(10):
    ax.plot(np.arange(steps), [freqs[i]]*raw_spec.shape[1], raw_spec[i])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-dab935fcdc39> in <module>
#       6 freqs = librosa.mel_frequencies()
#       7 for i in range(10):
# ----> 8     ax.plot(np.arange(raw_spec.shape[1]), freqs[i], raw_spec[i])
#       9
#
# ~/study/bandai/venv/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot(self, xs, ys, zdir, *args, **kwargs)
#    1421         zs = np.broadcast_to(zs, len(xs))
#    1422
# -> 1423         lines = super().plot(xs, ys, *args, **kwargs)
#    1424         for line in lines:
#    1425             art3d.line_2d_to_3d(line, zs=zs, zdir=zdir)
#
# ~/study/bandai/venv/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1644         """
#    1645         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...
